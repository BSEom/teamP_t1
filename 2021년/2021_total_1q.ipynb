# %%
import requests
from bs4 import BeautifulSoup


# 지역 이름과 코드 설정
region_name = "해운대구"
region_code = "18"

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": "2020-01-02",  # 검색 날짜
    "schCode": "0",
    "schLocale": region_code,  # 지역 코드
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 태그 추출
table = soup.find("table", class_="boardList")

# tr 태그 추출
if table:
    rows = table.find_all("tr")
    for i, row in enumerate(rows):
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        # td가 있고, 길이가 5 이상이면 필요한 항목만 추출
        if len(td_texts) >= 5:
            item_name = td_texts[0]       # 품목명
            spec = td_texts[1]            # 규격
            lowest_price = td_texts[2]    # 최저가
            highest_price = td_texts[3]   # 최고가
            avg_price = td_texts[4]       # 금주평균가
            print(f"[{i}] 품목: {item_name}, 규격: {spec}, 최저가: {lowest_price}, 최고가: {highest_price}, 금주평균가: {avg_price}, 지역: {region_name}")
else:
    print("boardList 테이블을 찾을 수 없습니다.")
# Out:
# [1] 품목: 가루비누, 규격: 세탁용세제(LG테크),가루형,3.0kg, 최저가: 7,425, 최고가: 12,675, 금주평균가: 9,425, 지역: 해운대구
# [2] 품목: 간장, 규격: 오복왕표 0.9ℓ 1병, 최저가: 6,300, 최고가: 7,250, 금주평균가: 6,633, 지역: 해운대구
# [3] 품목: 갈치, 규격: 60cm정도 500g 1마리(냉동), 최저가: 7,500, 최고가: 12,580, 금주평균가: 10,165, 지역: 해운대구
# [4] 품목: 고등어, 규격: 30㎝정도 500g 1마리, 최저가: 4,285, 최고가: 5,945, 금주평균가: 4,925, 지역: 해운대구
# [5] 품목: 달걀, 규격: 오경슈퍼란60g정도 10개, 최저가: , 최고가: 2,700, 금주평균가: 2,695, 지역: 해운대구
# [6] 품목: 닭고기, 규격: 육계 1.0㎏, 최저가: , 최고가: 7,635, 금주평균가: 5,998, 지역: 해운대구
# [7] 품목: 대파, 규격: 1.0㎏, 최저가: 2,743, 최고가: 3,490, 금주평균가: 3,066, 지역: 해운대구
# [8] 품목: 돼지고기, 규격: 삼겹살 500g, 최저가: 7,400, 최고가: 9,950, 금주평균가: 8,283, 지역: 해운대구
# [9] 품목: 두부, 규격: 500g 판두부(국산포장두부 420g) 1모, 최저가: 4,531, 최고가: 4,879, 금주평균가: 4,647, 지역: 해운대구
# [10] 품목: 라면, 규격: 신라면 120g 1봉지, 최저가: 676, 최고가: 676, 금주평균가: 676, 지역: 해운대구
# [11] 품목: 맥주, 규격: 하이트 500㎖ 1병, 최저가: 1,410, 최고가: 1,540, 금주평균가: 1,453, 지역: 해운대구
# [12] 품목: 무, 규격: 2.0㎏ 1개, 최저가: 2,350, 최고가: 4,983, 금주평균가: 3,511, 지역: 해운대구
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 지역 이름과 코드 설정
region_name = "부산진구"
region_code = "8"

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": "2020-01-02",  # 검색 날짜
    "schCode": "0",
    "schLocale": region_code,  # 지역 코드
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 태그 추출
table = soup.find("table", class_="boardList")

# tr 태그 추출
if table:
    rows = table.find_all("tr")
    for i, row in enumerate(rows):
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        # td가 있고, 길이가 5 이상이면 필요한 항목만 추출
        if len(td_texts) >= 5:
            item_name = td_texts[0]       # 품목명
            spec = td_texts[1]            # 규격
            lowest_price = td_texts[2]    # 최저가
            highest_price = td_texts[3]   # 최고가
            avg_price = td_texts[4]       # 금주평균가
            print(f"[{i}] 품목: {item_name}, 규격: {spec}, 최저가: {lowest_price}, 최고가: {highest_price}, 금주평균가: {avg_price}, 지역: {region_name}")
else:
    print("boardList 테이블을 찾을 수 없습니다.")
# Out:
# [1] 품목: 가루비누, 규격: 세탁용세제(LG테크),가루형,3.0kg, 최저가: 12,675, 최고가: 12,675, 금주평균가: 12,675, 지역: 부산진구
# [2] 품목: 간장, 규격: 오복왕표 0.9ℓ 1병, 최저가: 6,347, 최고가: 6,347, 금주평균가: 6,347, 지역: 부산진구
# [3] 품목: 갈치, 규격: 60cm정도 500g 1마리(냉동), 최저가: 11,204, 최고가: 11,204, 금주평균가: 11,204, 지역: 부산진구
# [4] 품목: 고등어, 규격: 30㎝정도 500g 1마리, 최저가: 5,684, 최고가: 5,684, 금주평균가: 5,684, 지역: 부산진구
# [5] 품목: 달걀, 규격: 오경슈퍼란60g정도 10개, 최저가: 2,890, 최고가: 2,890, 금주평균가: 2,890, 지역: 부산진구
# [6] 품목: 닭고기, 규격: 육계 1.0㎏, 최저가: 6,657, 최고가: 6,657, 금주평균가: 6,657, 지역: 부산진구
# [7] 품목: 대파, 규격: 1.0㎏, 최저가: 2,990, 최고가: 2,990, 금주평균가: 2,990, 지역: 부산진구
# [8] 품목: 돼지고기, 규격: 삼겹살 500g, 최저가: 9,950, 최고가: 9,950, 금주평균가: 9,950, 지역: 부산진구
# [9] 품목: 두부, 규격: 500g 판두부(국산포장두부 420g) 1모, 최저가: 4,531, 최고가: 4,531, 금주평균가: 4,531, 지역: 부산진구
# [10] 품목: 라면, 규격: 신라면 120g 1봉지, 최저가: 676, 최고가: 676, 금주평균가: 676, 지역: 부산진구
# [11] 품목: 맥주, 규격: 하이트 500㎖ 1병, 최저가: 1,540, 최고가: 1,540, 금주평균가: 1,540, 지역: 부산진구
# [12] 품목: 무, 규격: 2.0㎏ 1개, 최저가: 3,986, 최고가: 3,986, 금주평균가: 3,986, 지역: 부산진구
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 지역 이름과 코드 설정
region_name = "남구"
region_code = "5"

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": "2020-01-02",  # 검색 날짜
    "schCode": "0",
    "schLocale": region_code,  # 지역 코드
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 태그 추출
table = soup.find("table", class_="boardList")

# tr 태그 추출
if table:
    rows = table.find_all("tr")
    for i, row in enumerate(rows):
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        # td가 있고, 길이가 5 이상이면 필요한 항목만 추출
        if len(td_texts) >= 5:
            item_name = td_texts[0]       # 품목명
            spec = td_texts[1]            # 규격
            lowest_price = td_texts[2]    # 최저가
            highest_price = td_texts[3]   # 최고가
            avg_price = td_texts[4]       # 금주평균가
            print(f"[{i}] 품목: {item_name}, 규격: {spec}, 최저가: {lowest_price}, 최고가: {highest_price}, 금주평균가: {avg_price}, 지역: {region_name}")
else:
    print("boardList 테이블을 찾을 수 없습니다.")
# Out:
# [1] 품목: 가루비누, 규격: 세탁용세제(LG테크),가루형,3.0kg, 최저가: 7,837, 최고가: 8,175, 금주평균가: 8,006, 지역: 남구
# [2] 품목: 간장, 규격: 오복왕표 0.9ℓ 1병, 최저가: 6,300, 최고가: 6,300, 금주평균가: 6,300, 지역: 남구
# [3] 품목: 갈치, 규격: 60cm정도 500g 1마리(냉동), 최저가: 6,290, 최고가: 6,980, 금주평균가: 6,635, 지역: 남구
# [4] 품목: 고등어, 규격: 30㎝정도 500g 1마리, 최저가: 4,983, 최고가: 5,471, 금주평균가: 5,227, 지역: 남구
# [5] 품목: 달걀, 규격: 오경슈퍼란60g정도 10개, 최저가: 2,690, 최고가: 2,980, 금주평균가: 2,835, 지역: 남구
# [6] 품목: 닭고기, 규격: 육계 1.0㎏, 최저가: 4,995, 최고가: 5,280, 금주평균가: 5,138, 지역: 남구
# [7] 품목: 대파, 규격: 1.0㎏, 최저가: 2,990, 최고가: 3,873, 금주평균가: 3,432, 지역: 남구
# [8] 품목: 돼지고기, 규격: 삼겹살 500g, 최저가: 8,450, 최고가: 11,500, 금주평균가: 9,975, 지역: 남구
# [9] 품목: 두부, 규격: 500g 판두부(국산포장두부 420g) 1모, 최저가: 4,531, 최고가: 4,531, 금주평균가: 4,531, 지역: 남구
# [10] 품목: 라면, 규격: 신라면 120g 1봉지, 최저가: 676, 최고가: 676, 금주평균가: 676, 지역: 남구
# [11] 품목: 맥주, 규격: 하이트 500㎖ 1병, 최저가: 1,410, 최고가: 1,540, 금주평균가: 1,475, 지역: 남구
# [12] 품목: 무, 규격: 2.0㎏ 1개, 최저가: 3,784, 최고가: 5,760, 금주평균가: 4,772, 지역: 남구
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 지역 이름과 코드 설정
region_name = "동래구"
region_code = "7"

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": "2020-01-02",  # 검색 날짜
    "schCode": "0",
    "schLocale": region_code,  # 지역 코드
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 태그 추출
table = soup.find("table", class_="boardList")

# tr 태그 추출
if table:
    rows = table.find_all("tr")
    for i, row in enumerate(rows):
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        # td가 있고, 길이가 5 이상이면 필요한 항목만 추출
        if len(td_texts) >= 5:
            item_name = td_texts[0]       # 품목명
            spec = td_texts[1]            # 규격
            lowest_price = td_texts[2]    # 최저가
            highest_price = td_texts[3]   # 최고가
            avg_price = td_texts[4]       # 금주평균가
            print(f"[{i}] 품목: {item_name}, 규격: {spec}, 최저가: {lowest_price}, 최고가: {highest_price}, 금주평균가: {avg_price}, 지역: {region_name}")
else:
    print("boardList 테이블을 찾을 수 없습니다.")
# Out:
# [1] 품목: 가루비누, 규격: 세탁용세제(LG테크),가루형,3.0kg, 최저가: 7,420, 최고가: 8,175, 금주평균가: 7,798, 지역: 동래구
# [2] 품목: 간장, 규격: 오복왕표 0.9ℓ 1병, 최저가: 5,200, 최고가: 6,900, 금주평균가: 6,050, 지역: 동래구
# [3] 품목: 갈치, 규격: 60cm정도 500g 1마리(냉동), 최저가: 6,000, 최고가: 9,900, 금주평균가: 7,950, 지역: 동래구
# [4] 품목: 고등어, 규격: 30㎝정도 500g 1마리, 최저가: 4,000, 최고가: 4,125, 금주평균가: 4,063, 지역: 동래구
# [5] 품목: 달걀, 규격: 오경슈퍼란60g정도 10개, 최저가: 2,900, 최고가: 2,980, 금주평균가: 2,940, 지역: 동래구
# [6] 품목: 닭고기, 규격: 육계 1.0㎏, 최저가: 4,200, 최고가: 6,980, 금주평균가: 5,590, 지역: 동래구
# [7] 품목: 대파, 규격: 1.0㎏, 최저가: 2,842, 최고가: 3,000, 금주평균가: 2,921, 지역: 동래구
# [8] 품목: 돼지고기, 규격: 삼겹살 500g, 최저가: 6,400, 최고가: 7,800, 금주평균가: 7,100, 지역: 동래구
# [9] 품목: 두부, 규격: 500g 판두부(국산포장두부 420g) 1모, 최저가: 4,530, 최고가: 4,531, 금주평균가: 4,531, 지역: 동래구
# [10] 품목: 라면, 규격: 신라면 120g 1봉지, 최저가: 676, 최고가: 676, 금주평균가: 676, 지역: 동래구
# [11] 품목: 맥주, 규격: 하이트 500㎖ 1병, 최저가: 1,410, 최고가: 1,450, 금주평균가: 1,430, 지역: 동래구
# [12] 품목: 무, 규격: 2.0㎏ 1개, 최저가: 2,990, 최고가: 3,000, 금주평균가: 2,995, 지역: 동래구
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 지역 이름과 코드 설정
region_name = "사하구"
region_code = "12"

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": "2020-01-02",  # 검색 날짜
    "schCode": "0",
    "schLocale": region_code,  # 지역 코드
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 태그 추출
table = soup.find("table", class_="boardList")

# tr 태그 추출
if table:
    rows = table.find_all("tr")
    for i, row in enumerate(rows):
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        # td가 있고, 길이가 5 이상이면 필요한 항목만 추출
        if len(td_texts) >= 5:
            item_name = td_texts[0]       # 품목명
            spec = td_texts[1]            # 규격
            lowest_price = td_texts[2]    # 최저가
            highest_price = td_texts[3]   # 최고가
            avg_price = td_texts[4]       # 금주평균가
            print(f"[{i}] 품목: {item_name}, 규격: {spec}, 최저가: {lowest_price}, 최고가: {highest_price}, 금주평균가: {avg_price}, 지역: {region_name}")
else:
    print("boardList 테이블을 찾을 수 없습니다.")
# Out:
# [1] 품목: 가루비누, 규격: 세탁용세제(LG테크),가루형,3.0kg, 최저가: 6,742, 최고가: 7,425, 금주평균가: 7,084, 지역: 사하구
# [2] 품목: 간장, 규격: 오복왕표 0.9ℓ 1병, 최저가: 6,350, 최고가: 6,677, 금주평균가: 6,514, 지역: 사하구
# [3] 품목: 갈치, 규격: 60cm정도 500g 1마리(냉동), 최저가: 9,900, 최고가: 9,900, 금주평균가: 9,900, 지역: 사하구
# [4] 품목: 고등어, 규격: 30㎝정도 500g 1마리, 최저가: 4,393, 최고가: 5,544, 금주평균가: 4,969, 지역: 사하구
# [5] 품목: 달걀, 규격: 오경슈퍼란60g정도 10개, 최저가: 2,980, 최고가: 2,990, 금주평균가: 2,985, 지역: 사하구
# [6] 품목: 닭고기, 규격: 육계 1.0㎏, 최저가: 5,990, 최고가: 6,345, 금주평균가: 6,168, 지역: 사하구
# [7] 품목: 대파, 규격: 1.0㎏, 최저가: 3,350, 최고가: 3,571, 금주평균가: 3,461, 지역: 사하구
# [8] 품목: 돼지고기, 규격: 삼겹살 500g, 최저가: 8,400, 최고가: 8,950, 금주평균가: 8,675, 지역: 사하구
# [9] 품목: 두부, 규격: 500g 판두부(국산포장두부 420g) 1모, 최저가: 4,531, 최고가: 4,531, 금주평균가: 4,531, 지역: 사하구
# [10] 품목: 라면, 규격: 신라면 120g 1봉지, 최저가: 676, 최고가: 678, 금주평균가: 677, 지역: 사하구
# [11] 품목: 맥주, 규격: 하이트 500㎖ 1병, 최저가: 1,420, 최고가: 1,460, 금주평균가: 1,440, 지역: 사하구
# [12] 품목: 무, 규격: 2.0㎏ 1개, 최저가: 2,980, 최고가: 3,500, 금주평균가: 3,240, 지역: 사하구
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 지역 이름과 코드 설정
region_name = "북구"
region_code = "10"

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": "2020-01-02",  # 검색 날짜
    "schCode": "0",
    "schLocale": region_code,  # 지역 코드
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 태그 추출
table = soup.find("table", class_="boardList")

# tr 태그 추출
if table:
    rows = table.find_all("tr")
    for i, row in enumerate(rows):
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        # td가 있고, 길이가 5 이상이면 필요한 항목만 추출
        if len(td_texts) >= 5:
            item_name = td_texts[0]       # 품목명
            spec = td_texts[1]            # 규격
            lowest_price = td_texts[2]    # 최저가
            highest_price = td_texts[3]   # 최고가
            avg_price = td_texts[4]       # 금주평균가
            print(f"[{i}] 품목: {item_name}, 규격: {spec}, 최저가: {lowest_price}, 최고가: {highest_price}, 금주평균가: {avg_price}, 지역: {region_name}")
else:
    print("boardList 테이블을 찾을 수 없습니다.")
# Out:
# [1] 품목: 가루비누, 규격: 세탁용세제(LG테크),가루형,3.0kg, 최저가: 7,425, 최고가: 8,900, 금주평균가: 8,163, 지역: 북구
# [2] 품목: 간장, 규격: 오복왕표 0.9ℓ 1병, 최저가: 5,200, 최고가: 6,350, 금주평균가: 5,775, 지역: 북구
# [3] 품목: 갈치, 규격: 60cm정도 500g 1마리(냉동), 최저가: 4,000, 최고가: 9,900, 금주평균가: 6,950, 지역: 북구
# [4] 품목: 고등어, 규격: 30㎝정도 500g 1마리, 최저가: 3,125, 최고가: 3,500, 금주평균가: 3,313, 지역: 북구
# [5] 품목: 달걀, 규격: 오경슈퍼란60g정도 10개, 최저가: 2,500, 최고가: 2,980, 금주평균가: 2,740, 지역: 북구
# [6] 품목: 닭고기, 규격: 육계 1.0㎏, 최저가: 5,980, 최고가: 7,900, 금주평균가: 6,940, 지역: 북구
# [7] 품목: 대파, 규격: 1.0㎏, 최저가: 2,890, 최고가: 3,350, 금주평균가: 3,120, 지역: 북구
# [8] 품목: 돼지고기, 규격: 삼겹살 500g, 최저가: 8,400, 최고가: 8,900, 금주평균가: 8,650, 지역: 북구
# [9] 품목: 두부, 규격: 500g 판두부(국산포장두부 420g) 1모, 최저가: 1,500, 최고가: 4,531, 금주평균가: 3,016, 지역: 북구
# [10] 품목: 라면, 규격: 신라면 120g 1봉지, 최저가: 676, 최고가: 680, 금주평균가: 678, 지역: 북구
# [11] 품목: 맥주, 규격: 하이트 500㎖ 1병, 최저가: 1,440, 최고가: 1,460, 금주평균가: 1,450, 지역: 북구
# [12] 품목: 무, 규격: 2.0㎏ 1개, 최저가: 3,280, 최고가: 3,973, 금주평균가: 3,627, 지역: 북구
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 지역 이름과 코드 설정
region_name = "사상구"
region_code = "11"

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": "2020-01-02",  # 검색 날짜
    "schCode": "0",
    "schLocale": region_code,  # 지역 코드
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 태그 추출
table = soup.find("table", class_="boardList")

# tr 태그 추출
if table:
    rows = table.find_all("tr")
    for i, row in enumerate(rows):
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        # td가 있고, 길이가 5 이상이면 필요한 항목만 추출
        if len(td_texts) >= 5:
            item_name = td_texts[0]       # 품목명
            spec = td_texts[1]            # 규격
            lowest_price = td_texts[2]    # 최저가
            highest_price = td_texts[3]   # 최고가
            avg_price = td_texts[4]       # 금주평균가
            print(f"[{i}] 품목: {item_name}, 규격: {spec}, 최저가: {lowest_price}, 최고가: {highest_price}, 금주평균가: {avg_price}, 지역: {region_name}")
else:
    print("boardList 테이블을 찾을 수 없습니다.")
# Out:
# [1] 품목: 가루비누, 규격: 세탁용세제(LG테크),가루형,3.0kg, 최저가: 7,766, 최고가: 10,425, 금주평균가: 9,096, 지역: 사상구
# [2] 품목: 간장, 규격: 오복왕표 0.9ℓ 1병, 최저가: 11,900, 최고가: 11,900, 금주평균가: 11,900, 지역: 사상구
# [3] 품목: 갈치, 규격: 60cm정도 500g 1마리(냉동), 최저가: 8,000, 최고가: 8,500, 금주평균가: 8,250, 지역: 사상구
# [4] 품목: 고등어, 규격: 30㎝정도 500g 1마리, 최저가: 4,750, 최고가: 6,218, 금주평균가: 5,484, 지역: 사상구
# [5] 품목: 달걀, 규격: 오경슈퍼란60g정도 10개, 최저가: 2,890, 최고가: 2,920, 금주평균가: 2,905, 지역: 사상구
# [6] 품목: 닭고기, 규격: 육계 1.0㎏, 최저가: 7,990, 최고가: 8,880, 금주평균가: 8,435, 지역: 사상구
# [7] 품목: 대파, 규격: 1.0㎏, 최저가: 2,990, 최고가: 3,225, 금주평균가: 3,108, 지역: 사상구
# [8] 품목: 돼지고기, 규격: 삼겹살 500g, 최저가: 8,400, 최고가: 8,450, 금주평균가: 8,425, 지역: 사상구
# [9] 품목: 두부, 규격: 500g 판두부(국산포장두부 420g) 1모, 최저가: 4,415, 최고가: 4,531, 금주평균가: 4,473, 지역: 사상구
# [10] 품목: 라면, 규격: 신라면 120g 1봉지, 최저가: 676, 최고가: 3,380, 금주평균가: 2,028, 지역: 사상구
# [11] 품목: 맥주, 규격: 하이트 500㎖ 1병, 최저가: 1,400, 최고가: 1,410, 금주평균가: 1,405, 지역: 사상구
# [12] 품목: 무, 규격: 2.0㎏ 1개, 최저가: 3,322, 최고가: 5,760, 금주평균가: 4,541, 지역: 사상구
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display  # Jupyter Notebook에서 표 출력용

# 지역 이름과 코드 매핑
regions = {
    "남구": "5",
    "부산진구": "8",
    "해운대구": "18",
    "동래구": "7",
    "사하구": "12",
    "북구": "10",
    "사상구": "11"
}

# 날짜 설정
target_date = "2020-01-02"

# 데이터 수집 함수
def fetch_region_data(region_name, region_code):
    url = "https://www.busan.go.kr/depart/abnecessity01"
    params = {
        "isMart": "true",
        "kind": "",
        "schDate": target_date,
        "schCode": "0",
        "schLocale": region_code,
        "schMart": "0"
    }

    response = requests.get(url, params=params)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find("table", class_="boardList")

    region_data = []

    if table:
        rows = table.find_all("tr")
        for row in rows:
            tds = row.find_all("td")
            td_texts = [td.get_text(strip=True) for td in tds]
            if len(td_texts) >= 5:
                item_name = td_texts[0]
                spec = td_texts[1]
                try:
                    lowest_price = int(td_texts[2].replace(",", ""))
                except ValueError:
                    continue
                highest_price = td_texts[3]
                avg_price = td_texts[4]
                region_data.append([item_name, spec, lowest_price, highest_price, avg_price, region_name])
    return region_data

# 모든 지역에서 데이터 수집
all_data = []
for region_name, region_code in regions.items():
    all_data.extend(fetch_region_data(region_name, region_code))

# DataFrame 생성
columns = ["품목", "규격", "최저가", "최고가", "금주평균가", "지역"]
df = pd.DataFrame(all_data, columns=columns)

# 품목별 최저가인 행만 추출
min_price_df = df.loc[df.groupby("품목")["최저가"].idxmin()].reset_index(drop=True)

# 필요한 열만 선택
min_price_df = min_price_df[["품목", "규격", "최저가", "금주평균가", "지역"]]

# 표 출력 (Jupyter 환경일 경우)
display(min_price_df)

# 콘솔에서도 보기 좋게 출력하고 싶다면 아래도 사용 가능
# from tabulate import tabulate
# print(tabulate(min_price_df, headers='keys', tablefmt='fancy_grid'))

# CSV 저장 (선택)
# min_price_df.to_csv("최저가_정리.csv", index=False, encoding="utf-8-sig")
# Out:
#        품목                        규격    최저가   금주평균가    지역
# 0    가루비누     세탁용세제(LG테크),가루형,3.0kg   6742   7,084   사하구
# 1      간장              오복왕표 0.9ℓ 1병   5200   6,050   동래구
# 2      갈치       60cm정도 500g 1마리(냉동)   4000   6,950    북구
# 3     고등어            30㎝정도 500g 1마리   3125   3,313    북구
# 4      달걀            오경슈퍼란60g정도 10개   2500   2,740    북구
# 5     닭고기                   육계 1.0㎏   4200   5,590   동래구
# 6      대파                      1.0㎏   2743   3,066  해운대구
# 7    돼지고기                  삼겹살 500g   6400   7,100   동래구
# 8      두부  500g 판두부(국산포장두부 420g) 1모   1500   3,016    북구
# 9      라면              신라면 120g 1봉지    676     676    남구
# 10     맥주               하이트 500㎖ 1병   1400   1,405   사상구
# 11      무                   2.0㎏ 1개   2350   3,511  해운대구
# 12    밀가루             백설표 중력분1등2.5㎏   2690   2,885   사상구
# 13     밀감                100g 정도10개   1980   2,390   사상구
# 14      배            600g 정도 신고 10개  14234  30,153  해운대구
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display  # Jupyter Notebook에서 표 출력용

# 지역 이름과 코드 매핑
regions = {
    "남구": "5",
    "부산진구": "8",
    "해운대구": "18",
    "동래구": "7",
    "사하구": "12",
    "북구": "10",
    "사상구": "11"
}

# 날짜 설정
target_date = "2020-01-02"

# 데이터 수집 함수
def fetch_region_data(region_name, region_code):
    url = "https://www.busan.go.kr/depart/abnecessity01"
    params = {
        "isMart": "true",
        "kind": "",
        "schDate": target_date,
        "schCode": "0",
        "schLocale": region_code,
        "schMart": "0"
    }

    response = requests.get(url, params=params)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find("table", class_="boardList")

    region_data = []

    if table:
        rows = table.find_all("tr")
        for row in rows:
            tds = row.find_all("td")
            td_texts = [td.get_text(strip=True) for td in tds]
            if len(td_texts) >= 5:
                item_name = td_texts[0]
                spec = td_texts[1]
                try:
                    lowest_price = int(td_texts[2].replace(",", ""))
                    highest_price = int(td_texts[3].replace(",", ""))
                except ValueError:
                    continue
                avg_price = td_texts[4]
                region_data.append([item_name, spec, lowest_price, highest_price, avg_price, region_name])
    return region_data

# 모든 지역에서 데이터 수집
all_data = []
for region_name, region_code in regions.items():
    all_data.extend(fetch_region_data(region_name, region_code))

# DataFrame 생성
columns = ["품목", "규격", "최저가", "최고가", "금주평균가", "지역"]
df = pd.DataFrame(all_data, columns=columns)

# 품목별 최고가인 행만 추출
max_price_df = df.loc[df.groupby("품목")["최고가"].idxmax()].reset_index(drop=True)

# 필요한 열만 선택
max_price_df = max_price_df[["품목", "규격", "최고가", "금주평균가", "지역"]]

# 표 출력
display(max_price_df)

# 콘솔용 예쁘게 보기
# from tabulate import tabulate
# print(tabulate(max_price_df, headers='keys', tablefmt='fancy_grid'))
# Out:
#        품목                        규격    최고가   금주평균가    지역
# 0    가루비누     세탁용세제(LG테크),가루형,3.0kg  12675  12,675  부산진구
# 1      간장              오복왕표 0.9ℓ 1병  11900  11,900   사상구
# 2      갈치       60cm정도 500g 1마리(냉동)  12580  10,165  해운대구
# 3     고등어            30㎝정도 500g 1마리   6218   5,484   사상구
# 4      달걀            오경슈퍼란60g정도 10개   2990   2,985   사하구
# 5     닭고기                   육계 1.0㎏   8880   8,435   사상구
# 6      대파                      1.0㎏   3873   3,432    남구
# 7    돼지고기                  삼겹살 500g  11500   9,975    남구
# 8      두부  500g 판두부(국산포장두부 420g) 1모   4879   4,647  해운대구
# 9      라면              신라면 120g 1봉지   3380   2,028   사상구
# 10     맥주               하이트 500㎖ 1병   1540   1,475    남구
# 11      무                   2.0㎏ 1개   5760   4,772    남구
# 12    밀가루             백설표 중력분1등2.5㎏   3790   3,645   사하구
# 13     밀감                100g 정도10개   4663   3,674  해운대구
# 14      배            600g 정도 신고 10개  43300  30,153  해운대구
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display

# 지역 이름과 코드 매핑
regions = {
    "남구": "5",
    "부산진구": "8",
    "해운대구": "18",
    "동래구": "7",
    "사하구": "12",
    "북구": "10",
    "사상구": "11"
}

# 날짜 설정
target_date = "2020-01-02"

# 데이터 수집 함수
def fetch_region_data(region_name, region_code):
    url = "https://www.busan.go.kr/depart/abnecessity01"
    params = {
        "isMart": "true",
        "kind": "",
        "schDate": target_date,
        "schCode": "0",
        "schLocale": region_code,
        "schMart": "0"
    }

    response = requests.get(url, params=params)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find("table", class_="boardList")

    region_data = []

    if table:
        rows = table.find_all("tr")
        for row in rows:
            tds = row.find_all("td")
            td_texts = [td.get_text(strip=True) for td in tds]
            if len(td_texts) >= 5:
                item_name = td_texts[0]
                spec = td_texts[1]
                try:
                    lowest_price = int(td_texts[2].replace(",", ""))
                    highest_price = int(td_texts[3].replace(",", ""))
                except ValueError:
                    continue
                avg_price = td_texts[4]
                region_data.append([item_name, spec, lowest_price, highest_price, avg_price, region_name])
    return region_data

# 모든 지역에서 데이터 수집
all_data = []
for region_name, region_code in regions.items():
    all_data.extend(fetch_region_data(region_name, region_code))

# DataFrame 생성
columns = ["품목", "규격", "최저가", "최고가", "금주평균가", "지역"]
df = pd.DataFrame(all_data, columns=columns)

# 최저가와 최고가 각각 추출
min_df = df.loc[df.groupby("품목")["최저가"].idxmin()][["품목", "규격", "최저가", "지역", "금주평균가"]].reset_index(drop=True)
max_df = df.loc[df.groupby("품목")["최고가"].idxmax()][["품목", "최고가", "지역"]].reset_index(drop=True)

# 컬럼명 변경 (혼동 방지)
min_df = min_df.rename(columns={"지역": "최저가_지역"})
max_df = max_df.rename(columns={"지역": "최고가_지역"})

# 두 데이터프레임 병합
merged_df = pd.merge(min_df, max_df, on="품목")

# 최종 열 순서 정리
merged_df = merged_df[["품목", "규격", "최저가", "최저가_지역", "최고가", "최고가_지역", "금주평균가"]]

# 표 출력
display(merged_df)

# 콘솔 출력용 (선택)
# from tabulate import tabulate
# print(tabulate(merged_df, headers='keys', tablefmt='fancy_grid'))
# Out:
#        품목                        규격    최저가 최저가_지역    최고가 최고가_지역   금주평균가
# 0    가루비누     세탁용세제(LG테크),가루형,3.0kg   6742    사하구  12675   부산진구   7,084
# 1      간장              오복왕표 0.9ℓ 1병   5200    동래구  11900    사상구   6,050
# 2      갈치       60cm정도 500g 1마리(냉동)   4000     북구  12580   해운대구   6,950
# 3     고등어            30㎝정도 500g 1마리   3125     북구   6218    사상구   3,313
# 4      달걀            오경슈퍼란60g정도 10개   2500     북구   2990    사하구   2,740
# 5     닭고기                   육계 1.0㎏   4200    동래구   8880    사상구   5,590
# 6      대파                      1.0㎏   2743   해운대구   3873     남구   3,066
# 7    돼지고기                  삼겹살 500g   6400    동래구  11500     남구   7,100
# 8      두부  500g 판두부(국산포장두부 420g) 1모   1500     북구   4879   해운대구   3,016
# 9      라면              신라면 120g 1봉지    676     남구   3380    사상구     676
# 10     맥주               하이트 500㎖ 1병   1400    사상구   1540     남구   1,405
# 11      무                   2.0㎏ 1개   2350   해운대구   5760     남구   3,511
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display

# 지역 이름과 코드 매핑
regions = {
    "남구": "5",
    "부산진구": "8",
    "해운대구": "18",
    "동래구": "7",
    "사하구": "12",
    "북구": "10",
    "사상구": "11"
}

# 날짜 설정
target_date = "2021-01-07"

# 데이터 수집 함수
def fetch_region_data(region_name, region_code):
    url = "https://www.busan.go.kr/depart/abnecessity01"
    params = {
        "isMart": "true",
        "kind": "",
        "schDate": target_date,
        "schCode": "0",
        "schLocale": region_code,
        "schMart": "0"
    }

    response = requests.get(url, params=params)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find("table", class_="boardList")

    region_data = []

    if table:
        rows = table.find_all("tr")
        for row in rows:
            tds = row.find_all("td")
            td_texts = [td.get_text(strip=True) for td in tds]
            if len(td_texts) >= 5:
                item_name = td_texts[0]
                spec = td_texts[1]
                try:
                    lowest_price = int(td_texts[2].replace(",", ""))
                    highest_price = int(td_texts[3].replace(",", ""))
                except ValueError:
                    continue
                avg_price = td_texts[4]
                region_data.append([item_name, spec, lowest_price, highest_price, avg_price, region_name])
    return region_data

# 모든 지역에서 데이터 수집
all_data = []
for region_name, region_code in regions.items():
    all_data.extend(fetch_region_data(region_name, region_code))

# DataFrame 생성
columns = ["품목", "규격", "최저가", "최고가", "금주평균가", "지역"]
df = pd.DataFrame(all_data, columns=columns)

# 최저가, 최고가 각각 추출
min_df = df.loc[df.groupby("품목")["최저가"].idxmin()][["품목", "규격", "최저가", "지역", "금주평균가"]].reset_index(drop=True)
max_df = df.loc[df.groupby("품목")["최고가"].idxmax()][["품목", "최고가", "지역"]].reset_index(drop=True)

# 컬럼명 변경
min_df = min_df.rename(columns={"지역": "최저가_지역"})
max_df = max_df.rename(columns={"지역": "최고가_지역"})

# 병합
merged_df = pd.merge(min_df, max_df, on="품목")

# 가격 차이 계산
merged_df["가격차이"] = merged_df["최고가"] - merged_df["최저가"]
merged_df["차이비율(%)"] = (merged_df["가격차이"] / merged_df["최저가"] * 100).round(2).astype(str) + "%"

# 날짜 열 추가
merged_df["날짜"] = target_date

# 열 정리 및 출력
merged_df = merged_df[["날짜", "품목", "규격", "최저가", "최저가_지역", "최고가", "최고가_지역", "가격차이", "차이비율(%)", "금주평균가"]]

# 표 출력
display(merged_df)

# 저장하고 싶다면
merged_df.to_csv("2021_total_1q.csv", index=False, encoding="utf-8-sig")
# Out:
#             날짜     품목                        규격    최저가 최저가_지역    최고가 최고가_지역  \
# 0   2021-01-07   가루비누     세탁용세제(LG테크),가루형,3.0kg   5175    사상구  14850   부산진구
# 1   2021-01-07     간장              오복왕표 0.9ℓ 1병   5200     북구  11900    사상구
# 2   2021-01-07     갈치       60cm정도 500g 1마리(냉동)   6000     북구  18181   해운대구
# 3   2021-01-07    고등어            30㎝정도 500g 1마리   3800    사하구   7347   부산진구
# 4   2021-01-07     달걀            오경슈퍼란60g정도 10개   2980     남구   3490   부산진구
# 5   2021-01-07    닭고기                   육계 1.0㎏   5300   해운대구   9990    사상구
# 6   2021-01-07     대파                      1.0㎏   3228   해운대구   6414    동래구
# 7   2021-01-07   돼지고기                  삼겹살 500g   6900    동래구  17950   부산진구
# 8   2021-01-07     두부  500g 판두부(국산포장두부 420g) 1모   1500     북구   5194   부산진구
# 9   2021-01-07     라면              신라면 120g 1봉지    676     남구   3380    사상구
# 10  2021-01-07     맥주               하이트 500㎖ 1병   1410     남구   1540     남구
# ...
