# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display
from datetime import datetime

# 지역 이름과 코드 설정
region_name = "남구"
region_code = "5"
target_date = "2024-01-11"  # 날짜 열에 들어갈 날짜

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": target_date,
    "schCode": "0",
    "schLocale": region_code,
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find("table", class_="boardList")

# 결과 저장 리스트
result = []

# 데이터 수집
if table:
    rows = table.find_all("tr")
    for row in rows:
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        if len(td_texts) >= 5:
            item_name = td_texts[0]
            spec = td_texts[1]
            try:
                lowest_price = int(td_texts[2].replace(",", ""))
                highest_price = int(td_texts[3].replace(",", ""))
            except ValueError:
                continue
            avg_price = td_texts[4]
            
            price_diff = highest_price - lowest_price
            price_ratio = f"{round((price_diff / lowest_price) * 100, 2)}%"
            
            result.append([
                target_date, item_name, spec, lowest_price, region_name,
                highest_price, region_name, price_diff, price_ratio, avg_price
            ])
else:
    print("boardList 테이블을 찾을 수 없습니다.")

# DataFrame 생성 및 열 지정
columns = ["날짜", "품목", "규격", "최저가", "최저가_지역", "최고가", "최고가_지역", "가격차이", "차이비율(%)", "금주평균가"]
df = pd.DataFrame(result, columns=columns)

# 표 형태로 출력 (JupyterLab)
display(df)

df.to_csv("남구2024_1q.csv", index=False, encoding="utf-8-sig")
# Out:
#             날짜     품목                        규격    최저가 최저가_지역    최고가 최고가_지역  \
# 0   2024-01-11   가루비누     세탁용세제(LG테크),가루형,3.0kg   8175     남구   8925     남구
# 1   2024-01-11     간장              오복왕표 0.9ℓ 1병   7147     남구   7147     남구
# 2   2024-01-11     갈치       60cm정도 500g 1마리(냉동)   7633     남구  13200     남구
# 3   2024-01-11    고등어            30㎝정도 500g 1마리   5600     남구   5714     남구
# 4   2024-01-11     달걀            오경슈퍼란60g정도 10개   3990     남구   4280     남구
# 5   2024-01-11    닭고기                   육계 1.0㎏   8990     남구  10600     남구
# 6   2024-01-11     대파                      1.0㎏   2980     남구   5544     남구
# 7   2024-01-11   돼지고기                  삼겹살 500g  16800     남구  18450     남구
# 8   2024-01-11     두부  500g 판두부(국산포장두부 420g) 1모   3033     남구   5194     남구
# 9   2024-01-11     라면              신라면 120g 1봉지    780     남구    780     남구
# 10  2024-01-11     맥주               하이트 500㎖ 1병   1660     남구   1820     남구
# 11  2024-01-11      무                   2.0㎏ 1개   2105     남구   3180     남구
# 12  2024-01-11    밀가루             백설표 중력분1등2.5㎏   4420     남구   4600     남구
# 13  2024-01-11     밀감                100g 정도10개   4970     남구   9520     남구
# 14  2024-01-11      배            600g 정도 신고 10개  35800     남구  43176     남구
# 15  2024-01-11     배추                  2.0㎏ 1포기   2480     남구   3490     남구
# 16  2024-01-11  부엌용세제              참그린1.4㎏1봉리필용   4165     남구   9500     남구
# 17  2024-01-11   분말커피     맥심 스틱(커피믹스) 모카골드 100T  16450     남구  16480     남구
# 18  2024-01-11     사과             300g정도 부사 10개  16555     남구  32475     남구
# 19  2024-01-11    사이다              칠성 PET병 1.5ℓ   2816     남구   2880     남구
# 20  2024-01-11     설탕                백설표 정백당 1㎏   2380     남구   2380     남구
# 21  2024-01-11     소주              시원소주 360㎖ 1병   1330     남구   1350     남구
# 22  2024-01-11    쇠고기             한우등심 1등급 500g  59400     남구  72950     남구
# 23  2024-01-11    식용유                백설표콩기름1.8ℓ   6850     남구   6850     남구
# 24  2024-01-11      쌀                 정미포장미 20㎏  56900     남구  69900     남구
# 25  2024-01-11     양파                 1.0㎏-잎없는것   1655     남구   3111     남구
# 26  2024-01-11    오징어       25cm정도 500g 2마리(냉동)   6414     남구  15116     남구
# 27  2024-01-11     우유             부산우유 200㎖ 종이팩   1040     남구   1063     남구
# 28  2024-01-11    참기름               오뚜기 320㎖ 1병  10600     남구  10600     남구
# 29  2024-01-11   커피크림               동서 500g 리필용   2990     남구   3000     남구
# 30  2024-01-11     콜라            코카콜라 PET병 1.8ℓ   1980     남구   3730     남구
# 31  2024-01-11    화장지          뽀삐플러스30m×30롤(3겹)  31733     남구  34000     남구
#
#      가격차이  차이비율(%)   금주평균가
# 0     750    9.17%   8,550
# 1       0     0.0%   7,147
# 2    5567   72.93%  10,417
# 3     114    2.04%   5,657
# 4     290    7.27%   4,135
# 5    1610   17.91%   9,795
# 6    2564   86.04%   4,262
# 7    1650    9.82%  17,625
# 8    2161   71.25%   4,114
# 9       0     0.0%     780
# 10    160    9.64%   1,740
# 11   1075   51.07%   2,643
# 12    180    4.07%   4,510
# 13   4550   91.55%   7,245
# 14   7376    20.6%  39,488
# 15   1010   40.73%   2,985
# 16   5335  128.09%   6,833
# 17     30    0.18%  16,465
# 18  15920   96.16%  24,515
# 19     64    2.27%   2,848
# 20      0     0.0%   2,380
# 21     20     1.5%   1,340
# 22  13550   22.81%  66,175
# 23      0     0.0%   6,850
# 24  13000   22.85%  63,400
# 25   1456   87.98%   2,383
# 26   8702  135.67%  10,765
# 27     23    2.21%   1,052
# 28      0     0.0%  10,600
# 29     10    0.33%   2,995
# 30   1750   88.38%   2,855
# 31   2267    7.14%  32,867

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display
from datetime import datetime

# 지역 이름과 코드 설정
region_name = "남구"
region_code = "5"
target_date = "2024-04-11"  # 날짜 열에 들어갈 날짜

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": target_date,
    "schCode": "0",
    "schLocale": region_code,
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find("table", class_="boardList")

# 결과 저장 리스트
result = []

# 데이터 수집
if table:
    rows = table.find_all("tr")
    for row in rows:
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        if len(td_texts) >= 5:
            item_name = td_texts[0]
            spec = td_texts[1]
            try:
                lowest_price = int(td_texts[2].replace(",", ""))
                highest_price = int(td_texts[3].replace(",", ""))
            except ValueError:
                continue
            avg_price = td_texts[4]
            
            price_diff = highest_price - lowest_price
            price_ratio = f"{round((price_diff / lowest_price) * 100, 2)}%"
            
            result.append([
                target_date, item_name, spec, lowest_price, region_name,
                highest_price, region_name, price_diff, price_ratio, avg_price
            ])
else:
    print("boardList 테이블을 찾을 수 없습니다.")

# DataFrame 생성 및 열 지정
columns = ["날짜", "품목", "규격", "최저가", "최저가_지역", "최고가", "최고가_지역", "가격차이", "차이비율(%)", "금주평균가"]
df = pd.DataFrame(result, columns=columns)

# 표 형태로 출력 (JupyterLab)
display(df)

df.to_csv("남구2024_2q.csv", index=False, encoding="utf-8-sig")
# Out:
#             날짜     품목                        규격    최저가 최저가_지역    최고가 최고가_지역  \
# 0   2024-04-11   가루비누     세탁용세제(LG테크),가루형,3.0kg   5625     남구   9675     남구
# 1   2024-04-11     간장              오복왕표 0.9ℓ 1병   5294     남구   7147     남구
# 2   2024-04-11     갈치       60cm정도 500g 1마리(냉동)   5980     남구   9500     남구
# 3   2024-04-11    고등어            30㎝정도 500g 1마리   4975     남구   7142     남구
# 4   2024-04-11     달걀            오경슈퍼란60g정도 10개   3990     남구   4380     남구
# 5   2024-04-11    닭고기                   육계 1.0㎏   7990     남구   8725     남구
# 6   2024-04-11     대파                      1.0㎏   1484     남구   3655     남구
# 7   2024-04-11   돼지고기                  삼겹살 500g  10950     남구  19400     남구
# 8   2024-04-11     두부  500g 판두부(국산포장두부 420g) 1모   3033     남구   6056     남구
# 9   2024-04-11     라면              신라면 120g 1봉지    780     남구    780     남구
# 10  2024-04-11     맥주               하이트 500㎖ 1병   1660     남구   1820     남구
# 11  2024-04-11      무                   2.0㎏ 1개   3053     남구   3560     남구
# 12  2024-04-11    밀가루             백설표 중력분1등2.5㎏   4420     남구   4600     남구
# 13  2024-04-11     밀감                100g 정도10개   8320     남구  15544     남구
# 14  2024-04-11      배            600g 정도 신고 10개  40500     남구  65258     남구
# 15  2024-04-11     배추                  2.0㎏ 1포기   2480     남구   3877     남구
# 16  2024-04-11  부엌용세제              참그린1.4㎏1봉리필용   7900     남구   8330     남구
# 17  2024-04-11   분말커피     맥심 스틱(커피믹스) 모카골드 100T  16450     남구  16480     남구
# 18  2024-04-11     사과             300g정도 부사 10개  27800     남구  42475     남구
# 19  2024-04-11    사이다              칠성 PET병 1.5ℓ   2816     남구   2880     남구
# 20  2024-04-11     설탕                백설표 정백당 1㎏   2260     남구   2380     남구
# 21  2024-04-11     소주              시원소주 360㎖ 1병   1330     남구   1350     남구
# 22  2024-04-11    쇠고기             한우등심 1등급 500g  56900     남구  64950     남구
# 23  2024-04-11    식용유                백설표콩기름1.8ℓ   6850     남구   6850     남구
# 24  2024-04-11      쌀                 정미포장미 20㎏  44900     남구  47900     남구
# 25  2024-04-11     양파                 1.0㎏-잎없는것   2655     남구   3111     남구
# 26  2024-04-11    오징어       25cm정도 500g 2마리(냉동)   7000     남구  13815     남구
# 27  2024-04-11     우유             부산우유 200㎖ 종이팩   1040     남구   1063     남구
# 28  2024-04-11    참기름               오뚜기 320㎖ 1병  10600     남구  10600     남구
# 29  2024-04-11   커피크림               동서 500g 리필용   2990     남구   3000     남구
# 30  2024-04-11     콜라            코카콜라 PET병 1.8ℓ   2380     남구   2630     남구
# 31  2024-04-11    화장지          뽀삐플러스30m×30롤(3겹)  31733     남구  34000     남구
#
#      가격차이  차이비율(%)   금주평균가
# 0    4050    72.0%   7,650
# 1    1853    35.0%   6,221
# 2    3520   58.86%   7,740
# 3    2167   43.56%   6,059
# 4     390    9.77%   4,185
# 5     735     9.2%   8,358
# 6    2171  146.29%   2,570
# 7    8450   77.17%  15,175
# 8    3023   99.67%   4,545
# 9       0     0.0%     780
# 10    160    9.64%   1,740
# 11    507   16.61%   3,307
# 12    180    4.07%   4,510
# 13   7224   86.83%  11,932
# 14  24758   61.13%  52,879
# 15   1397   56.33%   3,179
# 16    430    5.44%   8,115
# 17     30    0.18%  16,465
# 18  14675   52.79%  35,138
# 19     64    2.27%   2,848
# 20    120    5.31%   2,320
# 21     20     1.5%   1,340
# 22   8050   14.15%  60,925
# 23      0     0.0%   6,850
# 24   3000    6.68%  46,400
# 25    456   17.18%   2,883
# 26   6815   97.36%  10,408
# 27     23    2.21%   1,052
# 28      0     0.0%  10,600
# 29     10    0.33%   2,995
# 30    250    10.5%   2,505
# 31   2267    7.14%  32,867

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display
from datetime import datetime

# 지역 이름과 코드 설정
region_name = "남구"
region_code = "5"
target_date = "2024-07-11"  # 날짜 열에 들어갈 날짜

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": target_date,
    "schCode": "0",
    "schLocale": region_code,
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find("table", class_="boardList")

# 결과 저장 리스트
result = []

# 데이터 수집
if table:
    rows = table.find_all("tr")
    for row in rows:
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        if len(td_texts) >= 5:
            item_name = td_texts[0]
            spec = td_texts[1]
            try:
                lowest_price = int(td_texts[2].replace(",", ""))
                highest_price = int(td_texts[3].replace(",", ""))
            except ValueError:
                continue
            avg_price = td_texts[4]
            
            price_diff = highest_price - lowest_price
            price_ratio = f"{round((price_diff / lowest_price) * 100, 2)}%"
            
            result.append([
                target_date, item_name, spec, lowest_price, region_name,
                highest_price, region_name, price_diff, price_ratio, avg_price
            ])
else:
    print("boardList 테이블을 찾을 수 없습니다.")

# DataFrame 생성 및 열 지정
columns = ["날짜", "품목", "규격", "최저가", "최저가_지역", "최고가", "최고가_지역", "가격차이", "차이비율(%)", "금주평균가"]
df = pd.DataFrame(result, columns=columns)

# 표 형태로 출력 (JupyterLab)
display(df)

df.to_csv("남구2024_3q.csv", index=False, encoding="utf-8-sig")
# Out:
#             날짜     품목                        규격    최저가 최저가_지역    최고가 최고가_지역  \
# 0   2024-07-11   가루비누     세탁용세제(LG테크),가루형,3.0kg   8925     남구   9675     남구
# 1   2024-07-11     간장              오복왕표 0.9ℓ 1병   7147     남구   9684     남구
# 2   2024-07-11     갈치       60cm정도 500g 1마리(냉동)   3980     남구  13200     남구
# 3   2024-07-11    고등어            30㎝정도 500g 1마리   4350     남구   6250     남구
# 4   2024-07-11     달걀            오경슈퍼란60g정도 10개   3990     남구   4380     남구
# 5   2024-07-11    닭고기                   육계 1.0㎏   8725     남구   8990     남구
# 6   2024-07-11     대파                      1.0㎏   2580     남구   3544     남구
# 7   2024-07-11   돼지고기                  삼겹살 500g  12450     남구  26900     남구
# 8   2024-07-11     두부  500g 판두부(국산포장두부 420g) 1모   3033     남구   6056     남구
# 9   2024-07-11     라면              신라면 120g 1봉지    780     남구    780     남구
# 10  2024-07-11     맥주               하이트 500㎖ 1병   1660     남구   1820     남구
# 11  2024-07-11      무                   2.0㎏ 1개   2990     남구   4360     남구
# 12  2024-07-11    밀가루             백설표 중력분1등2.5㎏   4290     남구   4420     남구
# 13  2024-07-11     밀감                100g 정도10개   9214     남구   9991     남구
# 14  2024-07-11      배            600g 정도 신고 10개  95960     남구  99500     남구
# 15  2024-07-11     배추                  2.0㎏ 1포기   3280     남구   5490     남구
# 16  2024-07-11  부엌용세제              참그린1.4㎏1봉리필용   8330     남구   9500     남구
# 17  2024-07-11   분말커피     맥심 스틱(커피믹스) 모카골드 100T  16450     남구  16480     남구
# 18  2024-07-11     사과             300g정도 부사 10개  23800     남구  38970     남구
# 19  2024-07-11    사이다              칠성 PET병 1.5ℓ   2880     남구   3066     남구
# 20  2024-07-11     설탕                백설표 정백당 1㎏   2330     남구   2330     남구
# 21  2024-07-11     소주              시원소주 360㎖ 1병   1330     남구   1350     남구
# 22  2024-07-11    쇠고기             한우등심 1등급 500g  49900     남구  59500     남구
# 23  2024-07-11    식용유                백설표콩기름1.8ℓ   8480     남구   8480     남구
# 24  2024-07-11      쌀                 정미포장미 20㎏  49900     남구  64900     남구
# 25  2024-07-11     양파                 1.0㎏-잎없는것   1933     남구   2052     남구
# 26  2024-07-11    오징어       25cm정도 500g 2마리(냉동)   5980     남구  13111     남구
# 27  2024-07-11     우유             부산우유 200㎖ 종이팩   1040     남구   1063     남구
# 28  2024-07-11    참기름               오뚜기 320㎖ 1병  10600     남구  10600     남구
# 29  2024-07-11   커피크림               동서 500g 리필용   2990     남구   3000     남구
# 30  2024-07-11     콜라            코카콜라 PET병 1.8ℓ   2380     남구   3730     남구
# 31  2024-07-11    화장지          뽀삐플러스30m×30롤(3겹)  23333     남구  24900     남구
#
#      가격차이  차이비율(%)   금주평균가
# 0     750     8.4%   9,300
# 1    2537    35.5%   8,416
# 2    9220  231.66%   8,590
# 3    1900   43.68%   5,300
# 4     390    9.77%   4,185
# 5     265    3.04%   8,858
# 6     964   37.36%   3,062
# 7   14450  116.06%  19,675
# 8    3023   99.67%   4,545
# 9       0     0.0%     780
# 10    160    9.64%   1,740
# 11   1370   45.82%   3,675
# 12    130    3.03%   4,355
# 13    777    8.43%   9,603
# 14   3540    3.69%  97,730
# 15   2210   67.38%   4,385
# 16   1170   14.05%   8,915
# 17     30    0.18%  16,465
# 18  15170   63.74%  31,385
# 19    186    6.46%   2,973
# 20      0     0.0%   2,330
# 21     20     1.5%   1,340
# 22   9600   19.24%  54,700
# 23      0     0.0%   8,480
# 24  15000   30.06%  57,400
# 25    119    6.16%   1,993
# 26   7131  119.25%   9,546
# 27     23    2.21%   1,052
# 28      0     0.0%  10,600
# 29     10    0.33%   2,995
# 30   1350   56.72%   3,055
# 31   1567    6.72%  24,117

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display
from datetime import datetime

# 지역 이름과 코드 설정
region_name = "남구"
region_code = "5"
target_date = "2024-10-17"  # 날짜 열에 들어갈 날짜

# 요청 URL 및 파라미터
url = "https://www.busan.go.kr/depart/abnecessity01"
params = {
    "isMart": "true",
    "kind": "",
    "schDate": target_date,
    "schCode": "0",
    "schLocale": region_code,
    "schMart": "0"
}

# 요청 보내기
response = requests.get(url, params=params)
response.encoding = 'utf-8'

# HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find("table", class_="boardList")

# 결과 저장 리스트
result = []

# 데이터 수집
if table:
    rows = table.find_all("tr")
    for row in rows:
        tds = row.find_all("td")
        td_texts = [td.get_text(strip=True) for td in tds]
        
        if len(td_texts) >= 5:
            item_name = td_texts[0]
            spec = td_texts[1]
            try:
                lowest_price = int(td_texts[2].replace(",", ""))
                highest_price = int(td_texts[3].replace(",", ""))
            except ValueError:
                continue
            avg_price = td_texts[4]
            
            price_diff = highest_price - lowest_price
            price_ratio = f"{round((price_diff / lowest_price) * 100, 2)}%"
            
            result.append([
                target_date, item_name, spec, lowest_price, region_name,
                highest_price, region_name, price_diff, price_ratio, avg_price
            ])
else:
    print("boardList 테이블을 찾을 수 없습니다.")

# DataFrame 생성 및 열 지정
columns = ["날짜", "품목", "규격", "최저가", "최저가_지역", "최고가", "최고가_지역", "가격차이", "차이비율(%)", "금주평균가"]
df = pd.DataFrame(result, columns=columns)

# 표 형태로 출력 (JupyterLab)
display(df)

df.to_csv("남구2024_4q.csv", index=False, encoding="utf-8-sig")
# Out:
#             날짜     품목                        규격    최저가 최저가_지역    최고가 최고가_지역  \
# 0   2024-10-17   가루비누     세탁용세제(LG테크),가루형,3.0kg   9675     남구   9675     남구
# 1   2024-10-17     간장              오복왕표 0.9ℓ 1병   7888     남구   9684     남구
# 2   2024-10-17     갈치       60cm정도 500g 1마리(냉동)   5980     남구  13200     남구
# 3   2024-10-17    고등어            30㎝정도 500g 1마리   3980     남구   6875     남구
# 4   2024-10-17     달걀            오경슈퍼란60g정도 10개   3990     남구   4380     남구
# 5   2024-10-17    닭고기                   육계 1.0㎏   7990     남구   9100     남구
# 6   2024-10-17     대파                      1.0㎏   2980     남구   3322     남구
# 7   2024-10-17   돼지고기                  삼겹살 500g  13950     남구  21900     남구
# 8   2024-10-17     두부  500g 판두부(국산포장두부 420g) 1모   3033     남구   6056     남구
# 9   2024-10-17     라면              신라면 120g 1봉지    780     남구    780     남구
# 10  2024-10-17     맥주               하이트 500㎖ 1병   1660     남구   1920     남구
# 11  2024-10-17      무                   2.0㎏ 1개   3990     남구   6960     남구
# 12  2024-10-17    밀가루             백설표 중력분1등2.5㎏   3860     남구   4420     남구
# 13  2024-10-17     밀감                100g 정도10개   5196     남구   8500     남구
# 14  2024-10-17      배            600g 정도 신고 10개  28560     남구  31142     남구
# 15  2024-10-17     배추                  2.0㎏ 1포기   8700     남구   9990     남구
# 16  2024-10-17  부엌용세제              참그린1.4㎏1봉리필용   6900     남구   8330     남구
# 17  2024-10-17   분말커피     맥심 스틱(커피믹스) 모카골드 100T  16450     남구  16480     남구
# 18  2024-10-17     사과             300g정도 부사 10개  19833     남구  37475     남구
# 19  2024-10-17    사이다              칠성 PET병 1.5ℓ   2880     남구   3066     남구
# 20  2024-10-17     설탕                백설표 정백당 1㎏   2330     남구   2330     남구
# 21  2024-10-17     소주              시원소주 360㎖ 1병   1330     남구   1350     남구
# 22  2024-10-17    쇠고기             한우등심 1등급 500g  59400     남구  69500     남구
# 23  2024-10-17    식용유                백설표콩기름1.8ℓ   8480     남구   8480     남구
# 24  2024-10-17      쌀                 정미포장미 20㎏  49900     남구  72900     남구
# 25  2024-10-17     양파                 1.0㎏-잎없는것   2211     남구   2347     남구
# 26  2024-10-17    오징어       25cm정도 500g 2마리(냉동)   7475     남구  13750     남구
# 27  2024-10-17     우유             부산우유 200㎖ 종이팩   1040     남구   1063     남구
# 28  2024-10-17    참기름               오뚜기 320㎖ 1병  11880     남구  11880     남구
# 29  2024-10-17   커피크림               동서 500g 리필용   2990     남구   3000     남구
# 30  2024-10-17     콜라            코카콜라 PET병 1.8ℓ   2680     남구   2890     남구
# 31  2024-10-17    화장지          뽀삐플러스30m×30롤(3겹)  15000     남구  31733     남구
#
#      가격차이  차이비율(%)   금주평균가
# 0       0     0.0%   9,675
# 1    1796   22.77%   8,786
# 2    7220  120.74%   9,590
# 3    2895   72.74%   5,428
# 4     390    9.77%   4,185
# 5    1110   13.89%   8,545
# 6     342   11.48%   3,151
# 7    7950   56.99%  17,925
# 8    3023   99.67%   4,545
# 9       0     0.0%     780
# 10    260   15.66%   1,790
# 11   2970   74.44%   5,475
# 12    560   14.51%   4,140
# 13   3304   63.59%   6,848
# 14   2582    9.04%  29,851
# 15   1290   14.83%   9,345
# 16   1430   20.72%   7,615
# 17     30    0.18%  16,465
# 18  17642   88.95%  28,654
# 19    186    6.46%   2,973
# 20      0     0.0%   2,330
# 21     20     1.5%   1,340
# 22  10100    17.0%  64,450
# 23      0     0.0%   8,480
# 24  23000   46.09%  61,400
# 25    136    6.15%   2,279
# 26   6275   83.95%  10,613
# 27     23    2.21%   1,052
# 28      0     0.0%  11,880
# 29     10    0.33%   2,995
# 30    210    7.84%   2,785
# 31  16733  111.55%  23,367

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
from matplotlib.font_manager import FontProperties

# 📌 강제로 폰트 지정
font_path = "C:/Windows/Fonts/malgun.ttf"
font_prop = FontProperties(fname=font_path)

# CSV 파일 불러오기
q1 = pd.read_csv("남구2024_1q.csv")
q2 = pd.read_csv("남구2024_2q.csv")
q3 = pd.read_csv("남구2024_3q.csv")
q4 = pd.read_csv("남구2024_4q.csv")

# 하나로 합치기
df_all = pd.concat([q1, q2, q3, q4], ignore_index=True)
df_all["날짜"] = pd.to_datetime(df_all["날짜"])

# 시각화
plt.figure(figsize=(14, 8))
sns.set(style="whitegrid")

# 선그래프
sns.lineplot(data=df_all, x="날짜", y="최저가", hue="품목", marker="o")

# 그래프 꾸미기 (여기서 FontProperties 적용!)
plt.title("2024년 남구 품목별 최저가 변화", fontsize=16, fontproperties=font_prop)
plt.xlabel("날짜", fontproperties=font_prop)
plt.ylabel("최저가 (원)", fontproperties=font_prop)
plt.xticks(rotation=45, fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
# plt.legend(loc="best", fontsize=9, ncol=2, prop=font_prop)
# plt.tight_layout()
# plt.show()
# ⭐ 범례를 그래프 바깥 오른쪽으로 이동
plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc='upper left',
    fontsize=9,
    ncol=1,
    prop=font_prop,
    borderaxespad=0
)

plt.tight_layout()
plt.show()


# df_all을 저장하는 코드
df_all.to_csv("남구2024_min.csv", index=False, encoding="utf-8-sig")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
from matplotlib.font_manager import FontProperties

# 📌 강제로 폰트 지정
font_path = "C:/Windows/Fonts/malgun.ttf"
font_prop = FontProperties(fname=font_path)

# CSV 파일 불러오기
q1 = pd.read_csv("남구2024_1q.csv")
q2 = pd.read_csv("남구2024_2q.csv")
q3 = pd.read_csv("남구2024_3q.csv")
q4 = pd.read_csv("남구2024_4q.csv")

# 하나로 합치기
df_all = pd.concat([q1, q2, q3, q4], ignore_index=True)
df_all["날짜"] = pd.to_datetime(df_all["날짜"])

# 시각화
plt.figure(figsize=(14, 8))
sns.set(style="whitegrid")

# 선그래프
sns.lineplot(data=df_all, x="날짜", y="최고가", hue="품목", marker="o")

# 그래프 꾸미기 (여기서 FontProperties 적용!)
plt.title("2024년 남구 품목별 최고가 변화", fontsize=16, fontproperties=font_prop)
plt.xlabel("날짜", fontproperties=font_prop)
plt.ylabel("최고가 (원)", fontproperties=font_prop)
plt.xticks(rotation=45, fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
# plt.legend(loc="best", fontsize=9, ncol=2, prop=font_prop)
# plt.tight_layout()
# plt.show()
# ⭐ 범례를 그래프 바깥 오른쪽으로 이동
plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc='upper left',
    fontsize=9,
    ncol=1,
    prop=font_prop,
    borderaxespad=0
)

plt.tight_layout()
plt.show()

# df_all을 저장하는 코드
df_all.to_csv("남구2024_max.csv", index=False, encoding="utf-8-sig")
